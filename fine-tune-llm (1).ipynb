# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install bitsandbytes
# !pip install wandb
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (2.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 12.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.1
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.3.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-cex6gc0p
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-cex6gc0p
#   Resolved https://github.com/huggingface/transformers to commit f91c16d270e5e3ff32fdb32ccf286d05c03dfa66
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (0.23.2)
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.43.0.dev0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.0.dev0) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.0.dev0) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.43.0.dev0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.43.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.43.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.43.0.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.43.0.dev0) (2024.2.2)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.43.0.dev0-py3-none-any.whl size=9341461 sha256=48061e6ac775c337e21f7d10d802d7c1f3021033796063c18f012c5571943a47
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zp6gwxpz/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed transformers-4.43.0.dev0

# %%
# !pip install git+https://github.com/huggingface/peft.git
# Out:
# Collecting git+https://github.com/huggingface/peft.git
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-ma5vo18_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-ma5vo18_
#   Resolved https://github.com/huggingface/peft.git to commit 018a1f49c4a6e500c243efac61d72341879ea9f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (2.1.2)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (4.43.0.dev0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (0.30.1)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.11.2.dev0) (0.23.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2024.3.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->peft==0.11.2.dev0) (3.1.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.11.2.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.11.2.dev0) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft==0.11.2.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.11.2.dev0) (1.3.0)
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.11.2.dev0-py3-none-any.whl size=258443 sha256=d55e663438f591bd1ee405804560c7c6cb0433811309aad13335c8a6be36f5b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g5jmeztk/wheels/d7/c7/de/1368fac8590e1b103ddc2ec2a28ad51d83aded1a3830e8a087
# Successfully built peft
# Installing collected packages: peft
# Successfully installed peft-0.11.2.dev0

# %%
# !pip install datasets accelerate huggingface_hub
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.19.2)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.30.1)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.23.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.32.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (2024.2.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# !pip install git+https://github.com/huggingface/trl.git
# Out:
# Collecting git+https://github.com/huggingface/trl.git
#   Cloning https://github.com/huggingface/trl.git to /tmp/pip-req-build-rae830zw
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/trl.git /tmp/pip-req-build-rae830zw
#   Resolved https://github.com/huggingface/trl.git to commit b6af2edc93b275afcee22a3eb71f9a5702ff9fd8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.9.5.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.9.5.dev0) (4.43.0.dev0)
# Requirement already satisfied: numpy<2.0.0,>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl==0.9.5.dev0) (1.26.4)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl==0.9.5.dev0) (0.30.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl==0.9.5.dev0) (2.19.2)
# Collecting tyro>=0.5.11 (from trl==0.9.5.dev0)
#   Downloading tyro-0.8.5-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.9.5.dev0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.9.5.dev0) (4.66.4)
# Collecting docstring-parser>=0.16 (from tyro>=0.5.11->trl==0.9.5.dev0)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.9.5.dev0) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl==0.9.5.dev0)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl==0.9.5.dev0) (5.9.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (2.2.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.9.5.dev0) (3.9.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.9.5.dev0) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->trl==0.9.5.dev0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.9.5.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.9.5.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.9.5.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.9.5.dev0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.9.5.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.9.5.dev0) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl==0.9.5.dev0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.9.5.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.9.5.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.9.5.dev0) (2023.4)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl==0.9.5.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.9.5.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.9.5.dev0) (1.16.0)
# Downloading tyro-0.8.5-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 4.2 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Building wheels for collected packages: trl
#   Building wheel for trl (pyproject.toml) ... done
#   Created wheel for trl: filename=trl-0.9.5.dev0-py3-none-any.whl size=244650 sha256=dea7166792f7ebcca04d33c3826f9b5ccec3ed50c683bdb75fa41502131ef0e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gpi_65wp/wheels/22/0e/42/319b77b2648bb6140ef2b08b0478ede9ca3cc7879fcd022d36
# Successfully built trl
# Installing collected packages: shtab, docstring-parser, tyro, trl
#   Attempting uninstall: docstring-parser
#     Found existing installation: docstring-parser 0.15
#     Uninstalling docstring-parser-0.15:
#       Successfully uninstalled docstring-parser-0.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# Successfully installed docstring-parser-0.16 shtab-1.7.1 trl-0.9.5.dev0 tyro-0.8.5

# %%
# pip install bitsandbytes accelerate
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(load_in_4bit=True)

checkpoint = "bigcode/starcoder2-3b"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained("bigcode/starcoder2-3b", quantization_config=quantization_config)

inputs = tokenizer.encode("def print_hello_world():", return_tensors="pt").to("cuda")
outputs = model.generate(inputs)
print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/442k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/12.1G [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1250: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:426: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# 2024-07-03 07:33:22.711787: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 07:33:22.711890: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 07:33:22.841768: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# def print_hello_world():
#     print("Hello World")
#
# print_hello_world

# %%
print(f"Memory footprint: {model.get_memory_footprint() / 1e6:.2f} MB")
# Out:
# Memory footprint: 1994.90 MB

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
import argparse
import multiprocessing
import os

import torch
import transformers
from accelerate import PartialState
from datasets import load_dataset
from peft import LoraConfig
from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    logging,
    set_seed,
)
from trl import SFTTrainer

# %%
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16,
    )

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
model = AutoModelForCausalLM.from_pretrained(
        "bigcode/starcoder2-3b",
        quantization_config=bnb_config,
        device_map={"": PartialState().process_index}
    )
print_trainable_parameters(model)
# Out:
# trainable params: 151369728 || all params: 1591200768 || trainable%: 9.5129245186488

# %%
from datasets import load_dataset
load_dataset("bigcode/the-stack-smol", data_dir="data/sql")
# Out:
# Downloading readme:   0%|          | 0.00/3.30k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/158M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['content', 'avg_line_length', 'max_line_length', 'alphanum_fraction', 'licenses', 'repository_name', 'path', 'size', 'lang'],
#         num_rows: 10000
#     })
# })

# %%
# Finetune input =>
def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--model_id", type=str, default="bigcode/starcoder2-3b")
    parser.add_argument("--dataset_name", type=str, default="bigcode/the-stack-smol")
    parser.add_argument("--subset", type=str, default="data/sql")
    parser.add_argument("--split", type=str, default="train")
    parser.add_argument("--dataset_text_field", type=str, default="content")

    parser.add_argument("--max_seq_length", type=int, default=512)
    parser.add_argument("--max_steps", type=int, default=1000)
    parser.add_argument("--micro_batch_size", type=int, default=1)
    parser.add_argument("--gradient_accumulation_steps", type=int, default=4)
    parser.add_argument("--weight_decay", type=float, default=0.01)
    parser.add_argument("--fp16", type=bool, default=True)

    parser.add_argument("--attention_dropout", type=float, default=0.1)
    parser.add_argument("--learning_rate", type=float, default=2e-4)
    parser.add_argument("--lr_scheduler_type", type=str, default="cosine")
    parser.add_argument("--warmup_steps", type=int, default=100)
    parser.add_argument("--seed", type=int, default=0)
    parser.add_argument("--output_dir", type=str, default="finetune_starcoder2-3b")
    parser.add_argument("--num_proc", type=int, default=None)
    parser.add_argument("--push_to_hub", type=bool, default=True)

    # Parse arguments
    args = parser.parse_args([])
    return args

# %%
lora_config = LoraConfig(
        r=8,
        target_modules=[
            "q_proj",
            "o_proj",
            "k_proj",
            "v_proj",
            "gate_proj",
            "up_proj",
            "down_proj",
        ],
        task_type="CAUSAL_LM",
    )

# %%
def main(args):
     
    token = os.environ.get("HF_TOKEN", None)

    data = load_dataset(
            args.dataset_name,
            data_dir=args.subset,
            split=args.split,
            token=token,
            num_proc=args.num_proc if args.num_proc else multiprocessing.cpu_count(),
        )

    # setup the trainer
    trainer = SFTTrainer(
              model=model,
              train_dataset=data,
              max_seq_length=args.max_seq_length,
              args=transformers.TrainingArguments(
                  per_device_train_batch_size=args.micro_batch_size,
                  gradient_accumulation_steps=args.gradient_accumulation_steps,
                  warmup_steps=args.warmup_steps,
                  max_steps=args.max_steps,
                  learning_rate=args.learning_rate,
                  lr_scheduler_type=args.lr_scheduler_type,
                  weight_decay=args.weight_decay,
                  fp16=args.fp16,
                  logging_strategy="steps",
                  logging_steps=10,
                  output_dir=args.output_dir,
                  optim="paged_adamw_8bit",
                  seed=args.seed,
                  run_name=f"train-{args.model_id.split('/')[-1]}",
                  report_to="wandb",
              ),
              peft_config=lora_config,
              dataset_text_field=args.dataset_text_field,
          )

        # launch
    print("Training...")
    trainer.train()

# %%
if __name__ == "__main__":
    
    args = get_args()
    set_seed(args.seed)
    
    logging.set_verbosity_error()
    main(args)
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length, dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1971: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1971: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:269: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:307: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Training...
# wandb: Currently logged in as: ayushsar45 (ayushsar_123). Use `wandb login --relogin` to force relogin
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240703_073524-xk2w5h97</code>
# Syncing run <strong><a href='https://wandb.ai/ayushsar_123/huggingface/runs/xk2w5h97' target="_blank">train-starcoder2-3b</a></strong> to <a href='https://wandb.ai/ayushsar_123/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ayushsar_123/huggingface' target="_blank">https://wandb.ai/ayushsar_123/huggingface</a>
#  View run at <a href='https://wandb.ai/ayushsar_123/huggingface/runs/xk2w5h97' target="_blank">https://wandb.ai/ayushsar_123/huggingface/runs/xk2w5h97</a>
# {'loss': 2.9653, 'grad_norm': 1.0301722288131714, 'learning_rate': 1.8e-05, 'epoch': 0.004}
# {'loss': 2.5532, 'grad_norm': 0.6296908855438232, 'learning_rate': 3.6e-05, 'epoch': 0.008}
# {'loss': 2.874, 'grad_norm': 1.2234957218170166, 'learning_rate': 5.6000000000000006e-05, 'epoch': 0.012}
# {'loss': 2.8488, 'grad_norm': 2.093595504760742, 'learning_rate': 7.6e-05, 'epoch': 0.016}
# {'loss': 2.3406, 'grad_norm': 0.8913716077804565, 'learning_rate': 9.6e-05, 'epoch': 0.02}
# {'loss': 2.6478, 'grad_norm': 2.693408250808716, 'learning_rate': 0.000116, 'epoch': 0.024}
# {'loss': 2.0952, 'grad_norm': 0.7017300724983215, 'learning_rate': 0.00013600000000000003, 'epoch': 0.028}
# {'loss': 2.0244, 'grad_norm': 1.4175968170166016, 'learning_rate': 0.00015600000000000002, 'epoch': 0.032}
# {'loss': 2.1475, 'grad_norm': 2.8231358528137207, 'learning_rate': 0.00017600000000000002, 'epoch': 0.036}
# {'loss': 2.1449, 'grad_norm': 2.1444060802459717, 'learning_rate': 0.000196, 'epoch': 0.04}
# {'loss': 1.8536, 'grad_norm': 2.5215871334075928, 'learning_rate': 0.00019996101150403543, 'epoch': 0.044}
# {'loss': 1.8096, 'grad_norm': 5.105021953582764, 'learning_rate': 0.00019980267284282717, 'epoch': 0.048}
# {'loss': 1.8182, 'grad_norm': 2.3581840991973877, 'learning_rate': 0.0001995227399981831, 'epoch': 0.052}
# {'loss': 1.5994, 'grad_norm': 4.030756950378418, 'learning_rate': 0.00019912155402515417, 'epoch': 0.056}
# {'loss': 2.1403, 'grad_norm': 2.0081136226654053, 'learning_rate': 0.0001985996037070505, 'epoch': 0.06}
# {'loss': 1.9659, 'grad_norm': 1.8365073204040527, 'learning_rate': 0.0001979575249599344, 'epoch': 0.064}
# {'loss': 1.5965, 'grad_norm': 2.35097599029541, 'learning_rate': 0.00019719610005785465, 'epoch': 0.068}
# {'loss': 1.9988, 'grad_norm': 1.9543477296829224, 'learning_rate': 0.00019631625667976583, 'epoch': 0.072}
# {'loss': 1.6373, 'grad_norm': 2.0192224979400635, 'learning_rate': 0.0001953190667792947, 'epoch': 0.076}
# {'loss': 1.8644, 'grad_norm': 2.4799182415008545, 'learning_rate': 0.00019420574527872968, 'epoch': 0.08}
# {'loss': 1.9592, 'grad_norm': 2.3135571479797363, 'learning_rate': 0.00019297764858882514, 'epoch': 0.084}
# {'loss': 1.7164, 'grad_norm': 7.316632270812988, 'learning_rate': 0.00019163627295622397, 'epoch': 0.088}
# {'loss': 1.6819, 'grad_norm': 1.8114264011383057, 'learning_rate': 0.0001901832526405114, 'epoch': 0.092}
# {'loss': 1.753, 'grad_norm': 2.202204942703247, 'learning_rate': 0.00018862035792312147, 'epoch': 0.096}
# {'loss': 1.5238, 'grad_norm': 3.4587340354919434, 'learning_rate': 0.0001869494929505219, 'epoch': 0.1}
# {'loss': 1.5258, 'grad_norm': 1.9646421670913696, 'learning_rate': 0.00018517269341430476, 'epoch': 0.104}
# {'loss': 1.8387, 'grad_norm': 3.857985734939575, 'learning_rate': 0.00018329212407100994, 'epoch': 0.108}
# {'loss': 1.8968, 'grad_norm': 1.0720417499542236, 'learning_rate': 0.00018131007610470276, 'epoch': 0.112}
# {'loss': 1.5427, 'grad_norm': 3.637821912765503, 'learning_rate': 0.00017922896433551907, 'epoch': 0.116}
# {'loss': 2.0511, 'grad_norm': 1.468931794166565, 'learning_rate': 0.00017705132427757895, 'epoch': 0.12}
# {'loss': 1.544, 'grad_norm': 1.2366758584976196, 'learning_rate': 0.0001747798090498532, 'epoch': 0.124}
# {'loss': 1.6498, 'grad_norm': 1.5767239332199097, 'learning_rate': 0.00017241718614374678, 'epoch': 0.128}
# {'loss': 1.578, 'grad_norm': 3.440232276916504, 'learning_rate': 0.00016996633405133655, 'epoch': 0.132}
# {'loss': 1.835, 'grad_norm': 2.620393991470337, 'learning_rate': 0.00016743023875837233, 'epoch': 0.136}
# {'loss': 1.773, 'grad_norm': 16.979005813598633, 'learning_rate': 0.0001648119901063131, 'epoch': 0.14}
# {'loss': 1.5828, 'grad_norm': 3.0815367698669434, 'learning_rate': 0.00016211477802783103, 'epoch': 0.144}
# {'loss': 1.5674, 'grad_norm': 1.5071206092834473, 'learning_rate': 0.00015934188866037016, 'epoch': 0.148}
# {'loss': 1.661, 'grad_norm': 4.2075676918029785, 'learning_rate': 0.0001564967003424938, 'epoch': 0.152}
# {'loss': 1.7086, 'grad_norm': 1.042335867881775, 'learning_rate': 0.00015358267949789966, 'epoch': 0.156}
# {'loss': 1.5542, 'grad_norm': 3.187805414199829, 'learning_rate': 0.00015060337641211637, 'epoch': 0.16}
# {'loss': 1.5645, 'grad_norm': 0.9754111766815186, 'learning_rate': 0.00014756242090702756, 'epoch': 0.164}
# {'loss': 1.3774, 'grad_norm': 1.4310095310211182, 'learning_rate': 0.00014446351791849276, 'epoch': 0.168}
# {'loss': 1.5053, 'grad_norm': 2.608905792236328, 'learning_rate': 0.0001413104429824542, 'epoch': 0.172}
# {'loss': 1.8344, 'grad_norm': 1.386284351348877, 'learning_rate': 0.00013810703763502744, 'epoch': 0.176}
# {'loss': 1.5116, 'grad_norm': 2.3750345706939697, 'learning_rate': 0.00013485720473218154, 'epoch': 0.18}
# {'loss': 1.5483, 'grad_norm': 5.192569732666016, 'learning_rate': 0.00013156490369471027, 'epoch': 0.184}
# {'loss': 1.5974, 'grad_norm': 1.6789488792419434, 'learning_rate': 0.00012823414568428768, 'epoch': 0.188}
# {'loss': 1.4905, 'grad_norm': 1.587874412536621, 'learning_rate': 0.0001248689887164855, 'epoch': 0.192}
# {'loss': 1.4701, 'grad_norm': 1.3183202743530273, 'learning_rate': 0.00012147353271670634, 'epoch': 0.196}
# {'loss': 1.6418, 'grad_norm': 2.9818668365478516, 'learning_rate': 0.00011805191452505602, 'epoch': 0.2}
# {'loss': 1.5006, 'grad_norm': 3.5795645713806152, 'learning_rate': 0.00011460830285624118, 'epoch': 0.204}
# {'loss': 1.4076, 'grad_norm': 1.3291130065917969, 'learning_rate': 0.00011114689322063255, 'epoch': 0.208}
# {'loss': 1.5088, 'grad_norm': 4.384085178375244, 'learning_rate': 0.00010767190281268187, 'epoch': 0.212}
# {'loss': 1.783, 'grad_norm': 2.1835105419158936, 'learning_rate': 0.00010418756537291996, 'epoch': 0.216}
# {'loss': 1.4774, 'grad_norm': 2.1997671127319336, 'learning_rate': 0.00010069812602979615, 'epoch': 0.22}
# {'loss': 1.462, 'grad_norm': 3.0356576442718506, 'learning_rate': 9.720783612764314e-05, 'epoch': 0.224}
# {'loss': 1.4627, 'grad_norm': 1.79197096824646, 'learning_rate': 9.372094804706867e-05, 'epoch': 0.228}
# {'loss': 1.2502, 'grad_norm': 1.8307868242263794, 'learning_rate': 9.024171002408506e-05, 'epoch': 0.232}
# {'loss': 1.3933, 'grad_norm': 2.1117587089538574, 'learning_rate': 8.677436097428775e-05, 'epoch': 0.236}
# {'loss': 1.6702, 'grad_norm': 3.39709210395813, 'learning_rate': 8.332312532838978e-05, 'epoch': 0.24}
# {'loss': 1.3699, 'grad_norm': 1.2886695861816406, 'learning_rate': 7.989220788540355e-05, 'epoch': 0.244}
# {'loss': 1.3791, 'grad_norm': 1.7079933881759644, 'learning_rate': 7.6485788689741e-05, 'epoch': 0.248}
# {'loss': 1.6473, 'grad_norm': 5.827482223510742, 'learning_rate': 7.310801793847344e-05, 'epoch': 0.252}
# {'loss': 1.5353, 'grad_norm': 2.098970413208008, 'learning_rate': 6.976301092495556e-05, 'epoch': 0.256}
# {'loss': 1.3781, 'grad_norm': 2.496155261993408, 'learning_rate': 6.64548430249745e-05, 'epoch': 0.26}
# {'loss': 1.3917, 'grad_norm': 1.0947504043579102, 'learning_rate': 6.318754473153221e-05, 'epoch': 0.264}
# {'loss': 1.2511, 'grad_norm': 1.1786088943481445, 'learning_rate': 5.9965096744310526e-05, 'epoch': 0.268}
# {'loss': 1.6538, 'grad_norm': 1.9480081796646118, 'learning_rate': 5.679142511980175e-05, 'epoch': 0.272}
# {'loss': 1.7832, 'grad_norm': 0.6877446174621582, 'learning_rate': 5.3670396488013854e-05, 'epoch': 0.276}
# {'loss': 1.5637, 'grad_norm': 2.6467254161834717, 'learning_rate': 5.0605813341576924e-05, 'epoch': 0.28}
# {'loss': 1.596, 'grad_norm': 6.340954303741455, 'learning_rate': 4.7601409402992106e-05, 'epoch': 0.284}
# {'loss': 1.4826, 'grad_norm': 0.9929534196853638, 'learning_rate': 4.46608450756656e-05, 'epoch': 0.288}
# {'loss': 1.4363, 'grad_norm': 1.9351576566696167, 'learning_rate': 4.1787702984271074e-05, 'epoch': 0.292}
# {'loss': 1.4866, 'grad_norm': 1.7035213708877563, 'learning_rate': 3.8985483609873244e-05, 'epoch': 0.296}
# {'loss': 1.4237, 'grad_norm': 4.877676963806152, 'learning_rate': 3.6257601025131026e-05, 'epoch': 0.3}
# {'loss': 1.6367, 'grad_norm': 1.9265737533569336, 'learning_rate': 3.360737873477584e-05, 'epoch': 0.304}
# {'loss': 1.6117, 'grad_norm': 1.1668897867202759, 'learning_rate': 3.103804562643302e-05, 'epoch': 0.308}
# {'loss': 1.4249, 'grad_norm': 1.233269453048706, 'learning_rate': 2.8552732036719687e-05, 'epoch': 0.312}
# {'loss': 1.3061, 'grad_norm': 6.29816198348999, 'learning_rate': 2.615446593741161e-05, 'epoch': 0.316}
# {'loss': 1.7541, 'grad_norm': 1.416440486907959, 'learning_rate': 2.3846169246326343e-05, 'epoch': 0.32}
# {'loss': 1.6331, 'grad_norm': 3.7647628784179688, 'learning_rate': 2.163065426741603e-05, 'epoch': 0.324}
# {'loss': 1.6129, 'grad_norm': 2.4769275188446045, 'learning_rate': 1.9510620264408596e-05, 'epoch': 0.328}
# {'loss': 1.7369, 'grad_norm': 2.4029276371002197, 'learning_rate': 1.7488650172170496e-05, 'epoch': 0.332}
# {'loss': 1.5359, 'grad_norm': 1.951714277267456, 'learning_rate': 1.5567207449798515e-05, 'epoch': 0.336}
# {'loss': 1.561, 'grad_norm': 1.4444122314453125, 'learning_rate': 1.3748633079274253e-05, 'epoch': 0.34}
# {'loss': 1.5997, 'grad_norm': 4.562813758850098, 'learning_rate': 1.2035142713338366e-05, 'epoch': 0.344}
# {'loss': 1.452, 'grad_norm': 1.7590007781982422, 'learning_rate': 1.042882397605871e-05, 'epoch': 0.348}
# {'loss': 1.611, 'grad_norm': 2.6885035037994385, 'learning_rate': 8.931633919382298e-06, 'epoch': 0.352}
# {'loss': 1.6957, 'grad_norm': 1.0573370456695557, 'learning_rate': 7.545396638768698e-06, 'epoch': 0.356}
# {'loss': 1.3318, 'grad_norm': 1.5116416215896606, 'learning_rate': 6.2718010508108545e-06, 'epoch': 0.36}
# {'loss': 1.2696, 'grad_norm': 0.687407910823822, 'learning_rate': 5.1123988355503475e-06, 'epoch': 0.364}
# {'loss': 1.5912, 'grad_norm': 4.76995849609375, 'learning_rate': 4.068602545994249e-06, 'epoch': 0.368}
# {'loss': 1.6367, 'grad_norm': 2.83550763130188, 'learning_rate': 3.1416838871368924e-06, 'epoch': 0.372}
# {'loss': 1.4799, 'grad_norm': 1.6518442630767822, 'learning_rate': 2.332772166583208e-06, 'epoch': 0.376}
# {'loss': 1.4915, 'grad_norm': 2.0769753456115723, 'learning_rate': 1.6428529186614195e-06, 'epoch': 0.38}
# {'loss': 1.4726, 'grad_norm': 4.269207000732422, 'learning_rate': 1.0727667037011668e-06, 'epoch': 0.384}
# {'loss': 1.4912, 'grad_norm': 3.066436529159546, 'learning_rate': 6.232080839403631e-07, 'epoch': 0.388}
# {'loss': 1.4664, 'grad_norm': 1.0808494091033936, 'learning_rate': 2.947247773079753e-07, 'epoch': 0.392}
# {'loss': 1.5225, 'grad_norm': 1.286550760269165, 'learning_rate': 8.771699011416168e-08, 'epoch': 0.396}
# {'loss': 1.488, 'grad_norm': 1.2414004802703857, 'learning_rate': 2.4369294605253166e-09, 'epoch': 0.4}
# {'train_runtime': 3549.5332, 'train_samples_per_second': 1.127, 'train_steps_per_second': 0.282, 'train_loss': 1.6811732816696168, 'epoch': 0.4}

# %%
def save(args):
    print("Saving the last checkpoint of the model")
    model.save_pretrained(os.path.join(args.output_dir, "final_checkpoint/"))

# %%
if __name__ == "__main__":
    
    args = get_args()
    os.makedirs(args.output_dir, exist_ok=True)
    
    save(args)

# %%
'''from peft import PeftConfig, PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer

config = PeftConfig.from_pretrained("AyushSar45/Fine_Tuned_SatarcoderV2")
base_model = "bigcode/starcoder2-3b"
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    load_in_4bit=True,
    torch_dtype=torch.float16,
    device_map="cuda",
)
model = PeftModel.from_pretrained(model, "AyushSar45/Fine_Tuned_SatarcoderV2")
tokenizer = AutoTokenizer.from_pretrained("AyushSar45/Fine_Tuned_SatarcoderV2")'''
# Out:
# 'from peft import PeftConfig, PeftModel\nfrom transformers import AutoModelForCausalLM, AutoTokenizer\n\nconfig = PeftConfig.from_pretrained("AyushSar45/Fine_Tuned_SatarcoderV2")\nbase_model = "bigcode/starcoder2-3b"\nmodel = AutoModelForCausalLM.from_pretrained(\n    base_model,\n    load_in_4bit=True,\n    torch_dtype=torch.float16,\n    device_map="cuda",\n)\nmodel = PeftModel.from_pretrained(model, "AyushSar45/Fine_Tuned_SatarcoderV2")\ntokenizer = AutoTokenizer.from_pretrained("AyushSar45/Fine_Tuned_SatarcoderV2")'

# %%
'''def generate_sql(question):
    eval_prompt = f"""You are a powerful text-to-SQL model. Your job is to answer questions about a database. You are given a question convert it into a SQL query.

    You must output the SQL query that answers the question.
    ### Input:
    {question}

    ### Response:
    """
    model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

    model.eval()
    with torch.no_grad():
        output = model.generate(
            **model_input,
            max_length=300,
            eos_token_id=tokenizer.eos_token_id,
        )
        response = tokenizer.decode(output[0], skip_special_tokens=True)
        return response.split("### Response:")[-1].strip()

iface = gr.Interface(
    fn=generate_sql,
    inputs=[gr.Textbox(label="Enter a question about the database")],
    outputs="text",
    title="Text-to-SQL Generator",
    description="Ask a question in natural language, and I'll generate the corresponding SQL query.",
)

iface.launch(debug=True)'''
# Out:
# 'def generate_sql(question):\n    eval_prompt = f"""You are a powerful text-to-SQL model. Your job is to answer questions about a database. You are given a question convert it into a SQL query.\n\n    You must output the SQL query that answers the question.\n    ### Input:\n    {question}\n\n    ### Response:\n    """\n    model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")\n\n    model.eval()\n    with torch.no_grad():\n        output = model.generate(\n            **model_input,\n            max_length=300,\n            eos_token_id=tokenizer.eos_token_id,\n        )\n        response = tokenizer.decode(output[0], skip_special_tokens=True)\n        return response.split("### Response:")[-1].strip()\n\niface = gr.Interface(\n    fn=generate_sql,\n    inputs=[gr.Textbox(label="Enter a question about the database")],\n    outputs="text",\n    title="Text-to-SQL Generator",\n    description="Ask a question in natural language, and I\'ll generate the corresponding SQL query.",\n)\n\niface.launch(debug=True)'
